# %%
from generate_data import *
# Out:
#            date   weekday   ingredient  supplier_id  initial_quantity  \
# 0    2023-06-01  Thursday        Flour            0           29097.0
# 1    2023-06-01  Thursday  Brown Sugar            1           14628.0
# 2    2023-06-01  Thursday       Butter            2           14787.0
# 3    2023-06-01  Thursday         Eggs            4             551.1
# 4    2023-06-01  Thursday     Cinnamon            6            1327.0
# ..          ...       ...          ...          ...               ...
# 325  2023-06-30    Friday     Molasses            9            8511.0
# 326  2023-06-30    Friday         Salt           12             912.5
# 327  2023-06-30    Friday      Vanilla           14             576.5
# 328  2023-06-30    Friday         Milk           15            8709.0
# 329  2023-06-30    Friday        Honey           16            4451.0
#
#      quantity_supplied  quantity_used  end_quantity  unit_cost
# 0              28958.0        28830.0       29225.0       0.50
# ...

# %%
# Get supplier data first
supplier_data = generate_supplier_data()

# Generate ingredient supply data for June 2023
start_date = datetime(2023, 6, 1)
end_date = datetime(2023, 6, 30)
df_ingredient_supply_data = generate_ingredient_supply_data(
    start_date, end_date, supplier_data
)

# %%
df_ingredient_supply_data
# Out:
#            date   weekday   ingredient  supplier_id  initial_quantity  \
# 0    2023-06-01  Thursday        Flour            1           14014.0
# 1    2023-06-01  Thursday  Brown Sugar            2            7193.0
# 2    2023-06-01  Thursday       Butter            4            7242.0
# 3    2023-06-01  Thursday         Eggs            6             315.2
# 4    2023-06-01  Thursday     Cinnamon            7             633.0
# ..          ...       ...          ...          ...               ...
# 325  2023-06-30    Friday     Molasses           11            9033.0
# 326  2023-06-30    Friday         Salt           12             873.0
# 327  2023-06-30    Friday      Vanilla           14             672.0
# 328  2023-06-30    Friday         Milk           15            9020.0
# 329  2023-06-30    Friday        Honey           16            4418.0
#
#      quantity_supplied  quantity_used  end_quantity  unit_cost
# 0              14109.0        13860.0       14263.0       0.50
# ...
